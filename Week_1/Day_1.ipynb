# %% [markdown]
# # Week Two
# ## Day 1 (Saturday)

# %% [markdown]
# ### Module 2, 3 and 4 Exercises

# %% [markdown]
# ### Module 2

# %% [markdown]
# #### Exercises: Level 1

# %%
firstname = 'Umar'
last_name = 'Zakariyya Muhammad'
fullname = 'Umar Zakariyya Muhammad'
country = 'Nigeria'
State = 'Bauchi State'
age = 25
year_of_Birth = 2000
is_married = False
is_true = True
is_light_on = True

#firstname, last_name, country, State, age, year_of_Birth : 'Umar', 'Zakariyya Muhammad', 'Nigeria', 'Bauchi State', 20, 2000
print(firstname)
print(last_name)
print(fullname)
print(country)
print(State)
print(age)
print(year_of_Birth)
print(is_married)
print(is_true)
print(is_light_on)
print(firstname, last_name, country, State, age, year_of_Birth)
# Out:
# Umar
# Zakariyya Muhammad
# Umar Zakariyya Muhammad
# Nigeria
# Bauchi State
# 25
# 2000
# False
# True
# True
# Umar Zakariyya Muhammad Nigeria Bauchi State 25 2000

# %%
#Check the data type of all your variables using type() built-in function
print(type(firstname))
print(type(last_name))
print(type(fullname))
print(type(country))
print(type(State))
print(type(age))
print(type(year_of_Birth))
print(type(is_married))
print(type(is_true))
print(type(is_light_on))
print(type("firstname, last_name, country, State, age, year_of_Birth"))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'str'>

# %%
import math

#Using the len() built-in function, find the length of your first name
first_name = 'Umar'
last_name = 'Zakariyya Muhammad'
country = 'Nigeria'
age = 25
len_first_name = (len(first_name))
len_last_name = (len(last_name))

#Compare the length of your first name and your last name
if len(first_name) > len(last_name):
    print('My Firstname is shorter than my lastname')
elif len(first_name) < len(last_name):
    print('My Firstname is shorter than my lastname')


#Declare 5 as num_one and 4 as num_two
num_one = 5
num_two = 4

#Add num_one and num_two and assign the value to a variable total
variable_total = num_one + num_two

#Subtract num_two from num_one and assign the value to a variable diff
variable_diff = num_one - num_two

#Multiply num_two and num_one and assign the value to a variable product
variable_product = num_two * num_one

#Divide num_one by num_two and assign the value to a variable division
variable_division = num_one/num_two

#Use modulus division to find num_two divided by num_one and assign the value to a variable remainder
variable_remainder = num_two % num_one

#Calculate num_one to the power of num_two and assign the value to a variable exp
variable_exp = num_one**num_two

#Find floor division of num_one by num_two and assign the value to a variable floor_division
floor_division = num_one//num_two

#The radius of a circle is 30 meters.
    #Calculate the area of a circle and assign the value to a variable name of area_of_circle
    #Calculate the circumference of a circle and assign the value to a variable name of circum_of_circle
    #Take radius as user input and calculate the area.

radius = 30

area_of_circle = math.pi *radius**2
circum_of_circle = 2 * math.pi * radius

user_radius = radius 
area_of_a_cirlce_with_user_radius = math.pi * user_radius ** 2

#Use the built-in input function to get first name, last name, country and age from a user and store the value to their corresponding variable names

first_name = input('Enter your First Name:')
last_name = input('Enter your Last Name')
country =  input('Enter your Country')
age =  input('Enter your Age')



print(len_first_name)
print(len_last_name)
print(variable_total)
print(variable_diff)
print(variable_product)
print(variable_division)
print(variable_remainder)
print(round(variable_remainder,2))
print(round(variable_exp,2))
print(floor_division)
print(area_of_circle)
print(circum_of_circle)
print(area_of_a_cirlce_with_user_radius)
print(f"First Name: {first_name}")
print(f"Last Name: {last_name}")
print(f"Country: {country}")
print(f"Age: {age}")

#Run help('keywords') in Python shell or in your file to check for the Python reserved words or keywords
help('keywords')
# Out:
# My Firstname is shorter than my lastname
# 4
# 18
# 9
# 1
# 20
# 1.25
# 4
# 4
# 625
# 1
# 2827.4333882308138
# 188.49555921538757
# 2827.4333882308138
# First Name: Umar
# Last Name: Zakariyya Muhammad
# Country: Nigeria
# Age: 25
#
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# ### Operators: Module 3

# %%
import math

#Declare your age as integer variable
age = 25
print(age)

#Declare your height as a float variable
my_height = 1.69
print(my_height)

#Declare a variable that store a complex number
Complex_Number = 3 + 4j
print(Complex_Number)
print(f'Complex Number: {Complex_Number}')

#Write a script that prompts the user to enter base and height of the triangle and calculate an area of this triangle (area = 0.5 x b x h).
b_base = 20
h_height = 10

area_of_triangle = (0.5*b_base*h_height)  
print(area_of_triangle)

#Write a script that prompts the user to enter side a, side b, and side c of the triangle. Calculate the perimeter of the triangle (perimeter = a + b + c).

side_a = 5
side_b = 4
side_c = 3
perimeter_of_a_triangle = (side_a+side_b+side_c)
print(perimeter_of_a_triangle)

#Get length and width of a rectangle using prompt. Calculate its area (area = length x width) and perimeter (perimeter = 2 x (length + width))
length_rectangle = float(6)
width_rectangnle = float(3)

area_rectangle = (length_rectangle*width_rectangnle)
perimeter_rectangle = (2*(length_rectangle*width_rectangnle))
print(area_rectangle)
print(perimeter_rectangle)

#Get radius of a circle using prompt. Calculate the area (area = pi x r x r) and circumference (c = 2 x pi x r) where pi = 3.14.

PI = float(3.142)
r_circle_area = float(7)

area_of_a_Circle = (PI *r_circle_area**2)
Circumference_of_a_Circle = (2 * PI *r_circle_area)
print(area_of_a_Circle)
print(Circumference_of_a_Circle)

#Calculate the slope, x-intercept and y-intercept of y = 2x -2

m_Slope = 2
y_intercept = -2
x_intercept = -y_intercept/m_Slope

print(m_Slope)
print(0,y_intercept)
print(x_intercept,0)

print(f'Slope is: {m_Slope}!')
print(f'Y-Intercept is: 0,{y_intercept}!')
print(f'X-Intercept is: {x_intercept}, 0!')


#Slope is (m = y2-y1/x2-x1). Find the slope and Euclidean distance between point (2, 2) and point (6,10)

x1,y1 = 2,2
x2,y2 = 6,10

#This is Slope
m_slope_I = (y2 - y1) / (x2 - x1)
print(m_slope_I)

#Euclidean Distance

Euclidean_Distance = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

Euclidean_Distance_round = round(Euclidean_Distance,2)
print(Euclidean_Distance_round)

#Compare the slopes in tasks 8 and 9.
m_Slope == m_slope_I

if  m_Slope == m_slope_I:
    print(f'All are thesaem')
else:
    print(f'All are not thesaem')


#Calculate the value of y (y = x^2 + 6x + 9). Try to use different x values and figure out at what x value y is going to be 0.
def calculate_y10(x10):
    return x10**2 + 6*x10 +9


x10_value = range(-10,10)
for x10 in x10_value:
    y10 = calculate_y10(x10)
    print(x10,y10)

for x10 in x10_value:
    if calculate_y10(x10) == 0:
        print(f"\nWhen y10 = 0, x10 = {x10}")

#Find the length of 'python' and 'dragon' and make a falsy comparison statement.

Comparison12 = len('python') == len('dragon')
print(Comparison12)
if  len('python') == len('dragon'):
    print('Yes, their length is all thesaeme')
else: 
    print('No, their length is all thesaeme')


#Use and operator to check if 'on' is found in both 'python' and 'dragon'

str2 = 'Python'
str3 = 'Dragon'

result = 'on' in str2 and 'on' in str3

print(result)

if  'on' in str2 and 'on' in str3:
    print('Yes, on found in both of them')
else:
    print('No, on does not found in both of them')


#I hope this course is not full of jargon. Use in operator to check if jargon is in the sentence.
sentence = 'I hope this course is not full of jargon'
result22 = 'jargon' in sentence
print(result22)

if 'jargon' in sentence:
    print('Yes, jargon is found in the sentence')
else:
    print('Yes, jargon is not found in the sentence')


#There is no 'on' in both dragon and python

result23 = 'on' not in str2 and 'on' not in str3
print(result23)

if  'on' not in str2 and 'on' not in str3:
    print("Yes, There's not on in both of them")
else: 
    print("No, There's on in both of them")


#Find the length of the text python and convert the value to float and convert it to string

text_str = 'Python'
Len_Python = (len(text_str))

int_Python = (float(Len_Python))

print(Len_Python)
print(int_Python)

#Even numbers are divisible by 2 and the remainder is zero. How do you check if a number is even or not using python?

number17 = 4

result_17 = number17%2

print(result_17)

if  number17 % 2 == 0:
    print(f'Yes, {number17} is Even Number')
else:
    print(f'No, {number17} is Odd Number')


#Check if the floor division of 7 by 3 is equal to the int converted value of 2.7.

Floor_division = 7//3
Integer_Value = int(2.7)

print(Floor_division)
print(Integer_Value)

Compare18 = Floor_division == Integer_Value
print(Compare18)

if  Floor_division == Integer_Value:
    print('Yes, All are Equal!')
else:
    print('No, All are Equal!')


#Check if type of '10' is equal to type of 10

Type1 = '10'
Type2 = 10
print(type('10'))
print(type(10))

Comparison19 = type('10') == type(10)
if  type('10') == type(10):
    print('Yes, They are All Equal!')
else:
    print('No, They are not All Equal!')

#Check if int('9.8') is equal to 10
# This QUestion need further clarification and Observation!!!
x20 = int(9.8)
y20 = 10
print(f"Is {x20} equal to 10?") 

#Writ a script that prompts the user to enter hours and rate per hour. Calculate pay of the person?
hours = float(40)
rate_per_hours = float(28)

Weekly_earning_per_person = hours * rate_per_hours
int_Weekly_earning_per_person = int(Weekly_earning_per_person)
print(Weekly_earning_per_person)
print(int_Weekly_earning_per_person)

#Write a script that prompts the user to enter number of years. Calculate the number of seconds a person can live. Assume a person can live hundred years

year_you_lived = 100
seconds_you_lived = year_you_lived * 365 * 24 * 3600

print(seconds_you_lived)

#Write a Python script that displays the following table
#1 1 1 1 1
#2 1 2 4 8
#3 1 3 9 27
#4 1 4 16 64
#5 1 5 25 125

for i in range(1, 6):
    square = i**2
    cube = i**3
    quadrant = i**4
    print(i, int(i/1), i**2, i**3)
# Out:
# 25
# 1.69
# (3+4j)
# Complex Number: (3+4j)
# 100.0
# 12
# 18.0
# 36.0
# 153.958
# 43.988
# 2
# 0 -2
# 1.0 0
# Slope is: 2!
# Y-Intercept is: 0,-2!
# X-Intercept is: 1.0, 0!
# 2.0
# 8.94
# All are thesaem
# -10 49
# -9 36
# -8 25
# -7 16
# -6 9
# -5 4
# -4 1
# -3 0
# -2 1
# -1 4
# 0 9
# 1 16
# 2 25
# 3 36
# 4 49
# 5 64
# 6 81
# 7 100
# 8 121
# 9 144
#
# When y10 = 0, x10 = -3
# True
# Yes, their length is all thesaeme
# True
# Yes, on found in both of them
# True
# Yes, jargon is found in the sentence
# False
# No, There's on in both of them
# 6
# 6.0
# 0
# Yes, 4 is Even Number
# 2
# 2
# True
# Yes, All are Equal!
# <class 'str'>
# <class 'int'>
# No, They are not All Equal!
# Is 9 equal to 10?
# 1120.0
# 1120
# 3153600000
# 1 1 1 1
# 2 2 4 8
# 3 3 9 27
# 4 4 16 64
# 5 5 25 125

# %% [markdown]
# ### Strings: Module 4

# %%
#1Concatenate the string 'Thirty', 'Days', 'Of', 'Python' to a single string, 'Thirty Days Of Python'.

challenge1 = 'Thirty', 'Days', 'Of', 'Python'
concatinate1_the_string = ' '.join(challenge1)
print(concatinate1_the_string)

#2Concatenate the string 'Coding', 'For' , 'All' to a single string, 'Coding For All'.

challenge2 = 'Coding', 'For' , 'All'
concatinate2_the_string = ' '.join(challenge2)
print(concatinate2_the_string)


#3Declare a variable named company and assign it to an initial value "Coding For All".

name3 = 'Geo Data Solutions'
value3 = 'Coding For All'

join_company = '{} {}' .format(name3,value3)
print(join_company)

#4Print the variable company using print().

print(join_company)

#5Print the length of the company string using len() method and print().

Length5 = len(join_company)
print(Length5)

#6Change all the characters to uppercase letters using upper() method.

Upper_Company = (join_company.upper())

print(Upper_Company)

#7Change all the characters to lowercase letters using lower() method.

Lower_Company = (join_company.lower())

print(Lower_Company)

#8Use capitalize(), title(), swapcase() methods to format the value of the string Coding For All.

#Capitalize
Capitalize_Company = (value3.capitalize())

print(Capitalize_Company)

#title
Title8_Company = (value3.title())

print(Title8_Company)

#swapcase
Swapcase_Company = (value3.swapcase())

print(Swapcase_Company)


#9Cut(slice) out the first word of Coding For All string.

Slice8 = value3.split()

print(Slice8)

#10Check if Coding For All string contains a word Coding using the method index, find or other methods.

print('Coding' in value3)

if  'Coding' in value3:
    print('Yes, Coding in', value3,'!')
else:
    print('No, Coding in', value3,'!')

#11Replace the word coding in the string 'Coding For All' to Python.

value3 
Replacement_11 = (value3.replace('Coding', 'Python'))
print(Replacement_11)


#12Change Python for Everyone to Python for All using the replace method or other methods.

value4 = 'Python for Everyone'
Change12 = (value4.replace('Everyone','All'))
print(Change12)

#13Split the string 'Coding For All' using space as the separator (split()).

split13 = (value3.split())
print(split13)

#14 "Facebook, Google, Microsoft, Apple, IBM, Oracle, Amazon" split the string at the comma.

value14 = "Facebook Google Microsoft Apple IBM Oracle Amazon"
split14 = (value14.split())
print(split14)


#15What is the character at index 0 in the string Coding For All.

What_character_at_0 = value3[0]
print(What_character_at_0)
print(f'Character {What_character_at_0} is at the index 0!')

#16What is the last index of the string Coding For All.

What_character_at_last = (len(value3) -1) 
print(What_character_at_last)
print(f'The Last Index in {value3} is {What_character_at_last}!')

#17What character is at index 10 in "Coding For All" string.

What_character_at_10 = value3[10]
print(What_character_at_10)
print(f'Character {What_character_at_10} is at the index 10!. \nHence its a Blank Character (Space)')

#18Create an acronym or an abbreviation for the name 'Python For Everyone'.

value4
Acronyms18 = ''.join([letter[0] for letter in "Python For Everyone".split()])
print(Acronyms18)

#19Create an acronym or an abbreviation for the name 'Coding For All'.

value3
Acronyms19 = ''.join([letter19[0] for letter19 in "Coding For All".split()])
print(Acronyms19)

#20 Use index to determine the position of the first occurrence of C in Coding For All.

First_Occurence_20 = (value3.index('C'))
print(First_Occurence_20)
print(f'The Position of the First of C in {value3} is 0!')


#21Use index to determine the position of the first occurrence of F in Coding For All.

First_Occurence_21 = (value3.index('F'))
print(First_Occurence_21)
print(f'The Position of the First Occurence of F in {value3} is 7!')

#22 Use rfind to determine the position of the last occurrence of l in Coding For All People.

value22 = 'Coding For All People'
Last_Occurence_22 = (value22.rfind('l'))
print(Last_Occurence_22)
print(f'The Position of the Last Occurence of l in {value22} is 19!')

#23 Use index or find to find the position of the first occurrence of the word 'because' in the following sentence: 'You cannot end a sentence with because because because is a conjunction'

sentence23 = 'You cannot end a sentence with because because because is a conjunction'
Position_of_First_Occurence = (sentence23.index('because'))
print(Position_of_First_Occurence)
print(f'The Position of the First occurence of because in {sentence23} is 31!')


#24Use rindex to find the position of the last occurrence of the word because in the following sentence: 'You cannot end a sentence with because because because is a conjunction'

Position_of_Last_Occurence = (sentence23.rindex('because'))
print(Position_of_Last_Occurence)
print(f'The Position of the Last occurence of because in {sentence23} is 47!')

#25 Slice out the phrase 'because because because' in the following sentence: 'You cannot end a sentence with because because because is a conjunction'

start = sentence23.find('because')
end = sentence23.rindex('because') 
print(start)
print(end)
print(sentence23[:start] + sentence23[end:])

#26 Find the position of the first occurrence of the word 'because' in the following sentence: 'You cannot end a sentence with because because because is a conjunction'

sentence23 = 'You cannot end a sentence with because because because is a conjunction'
Position_of_First_Occurence26 = (sentence23.index('because'))
print(Position_of_First_Occurence26)
print(f'The Position of the First occurence of because in {sentence23} is 31!')


#27 Slice out the phrase 'because because because' in the following sentence: 'You cannot end a sentence with because because because is a conjunction'

start = sentence23.find('because')
end = sentence23.rindex('because') 
print(start)
print(end)
print(sentence23[:start] + sentence23[end:])

#29 Does ''Coding For All' start with a substring Coding?

Startwith29 = (value3.startswith('Coding'))
print(Startwith29)
if  (value3.startswith('Coding')):
    print(f"Yes, {value3} end with Coding!")
else:
    print(f"No, {value3}doesn't end with Coding!")

#29 Does 'Coding For All' end with a substring coding?

Endwith29 = (value3.endswith('Coding'))
print(Endwith29)
if  (value3.endswith('Coding')):
    print(f"Yes, {value3} Start with Coding!")
else:
    print(f"No, {value3} doesn't Start with Coding!")


#30 '   Coding For All      '  , remove the left and right trailing spaces in the given string.

value30 = '   Coding For All      '
Space_Trimmed = value30.strip()

print(Space_Trimmed)

#31Which one of the following variables return True when we use the method isidentifier():
#30DaysOfPython
#thirty_days_of_python

#30DaysOfPython

value31 = '30DaysOfPython'
value311 = 'thirty_days_of_python'

identifier31 = (value31.isidentifier())

if  (value31.isidentifier()):
    print(f'Yes, {value31} is an Identifier!')
else:
    print(f'No, {value31} is not Identifier!')

#thirty_days_of_python

identifier311 = (value311.isidentifier())

if  (value311.isidentifier()):
    print(f'Yes, {value311} is an Identifier!')
else:
    print(f'No, {value311} is not Identifier!')

#32 The following list contains the names of some of python libraries: ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']. Join the list with a hash with space string.

python_libraries = ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']

Join_python_Lib = ' #'.join(python_libraries)

print(Join_python_Lib)


#33 Use the new line escape sequence to separate the following sentences.
#I am enjoying this challenge.
#I just wonder what is next.

sentence33 = 'I am enjoying this challenge.'
sentence333 = 'I just wonder what is next.'

New_Line_Escape = ('I am enjoying this challenge.\nI just wonder what is next.')
print(New_Line_Escape)

#34Use a tab escape sequence to write the following lines.
#Name      Age     Country   City
#Asabeneh  250     Finland   Helsinki

Title = ('Name\tAge\tCountry\tCity')
No_1 = ('Umar\t25\tNigeria\tBauchi')

print(Title)
print(No_1)


#Use the string formatting method to display the following:
radius = 10
area = 3.14 * radius ** 2
#The area of a circle with radius 10 is 314 meters square.

print(f'The area of a circle with radius {radius} is {int(area)} meters square.')


#Make the following using string formatting methods:

a,b = 8,6

print(f"{a} + {b} = {a + b}")
print(f"{a} - {b} = {a - b}")
print(f"{a} * {b} = {a * b}")
print(f"{a} / {b} = {a / b:.3f}")
print(f"{a} % {b} = {a % b}")
print(f"{a} // {b} = {a // b}")
print(f"{a} ** {b} = {a ** b}")
# Out:
# Thirty Days Of Python
# Coding For All
# Geo Data Solutions Coding For All
# Geo Data Solutions Coding For All
# 33
# GEO DATA SOLUTIONS CODING FOR ALL
# geo data solutions coding for all
# Coding for all
# Coding For All
# cODING fOR aLL
# ['Coding', 'For', 'All']
# True
# Yes, Coding in Coding For All !
# Python For All
# Python for All
# ['Coding', 'For', 'All']
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
# C
# Character C is at the index 0!
# 13
# The Last Index in Coding For All is 13!
#
# Character   is at the index 10!.
# Hence its a Blank Character (Space)
# PFE
# CFA
# 0
# The Position of the First of C in Coding For All is 0!
# 7
# The Position of the First Occurence of F in Coding For All is 7!
# 19
# The Position of the Last Occurence of l in Coding For All People is 19!
# 31
# The Position of the First occurence of because in You cannot end a sentence with because because because is a conjunction is 31!
# 47
# ...
